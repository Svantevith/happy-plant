# %%
import numpy as np
import pathlib
import os
import glob
import shutil
import re
import cv2
import pandas as pd
import pickle
import matplotlib.pyplot as plt

from math import ceil
from PIL import Image
from datetime import datetime

from sklearn.preprocessing import LabelBinarizer, MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import precision_score, recall_score, f1_score

import tensorflow as tf
from keras import backend as K
from keras import Input
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import GlobalAveragePooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img, array_to_img
from keras.optimizers import Adam
from keras.models import Model, load_model
from keras.losses import BinaryCrossentropy
from keras.applications.vgg16 import VGG16
from keras.applications.mobilenet import MobileNet
from keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
from keras.applications.inception_v3 import InceptionV3
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.metrics import Accuracy, Precision, Recall, CategoricalAccuracy

tf.compat.v1.ConfigProto().gpu_options.allow_growth = True
tf.config.run_functions_eagerly(False)

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# # Load data

# %%
# Directories containing input data
AUGMENTED_DATA = os.path.join('data', 'Plant_leave_diseases_dataset_with_augmentation')
RAW_DATA = os.path.join('data', 'Plant_leave_diseases_dataset_without_augmentation')
DATA_DIRECTORY = os.path.join('data', 'PlantVillage')
MODELS_DIRECTORY = os.path.join('data', 'models')
LABELS_DIRECTORY = os.path.join('data', 'models', 'labels')

LABELS = [
    "Scab",
    "Black_Rot",
    "Rust",
    "Background",
    "Healthy",
    "Powdery_Mildew",
    "Leaf_Spot",
    "Bacterial_Spot",
    "Target_Spot",
    "Mosaic_Virus",
    "Yellow_Leaf_Curl_Virus",
    "Leaf_Scorch",
    "Leaf_Mold",
    "Spider_Mites",
    "Black_Measles",
    "Citrus_Greening",
    "Blight"
]

# Dimensions of resized image
IMAGE_SIZE = (224, 224)

INPUT_SHAPE = (*IMAGE_SIZE, 3)

# Due to memory limitations a smaller portion of input images needs to be taken.
IMAGE_LIMIT = 12500

# %%
def transform_image(image_path: str, image_size: tuple):
    image = cv2.imread(image_path)
    resized_image = cv2.resize(image, image_size)
    transformed_image =  img_to_array(resized_image)
    return transformed_image

# %%
def clean_label(label: str) -> str:
    whitespace = label.find(' ')
    if whitespace > -1:
        label = f"{label[:whitespace]}_({label[whitespace + 1:].replace(' ', '_')})"
    
    floor = re.search('_{2,}', label)
    if floor:
        regex = re.compile('(_?tomato_?|_?apple_?)', re.IGNORECASE)
        label = re.sub(regex, '_', label[floor.end():])
    
    return label.title().strip('_')

# %%
def unpack(data):
    for value in data.values():
        if isinstance(value, dict):
            yield from unpack(value)
        else:
            if isinstance(value, list):
                yield np.asarray(value)
            else:
                yield value

# %%
def search_for_label(folder):
    for label in LABELS:
        if label in folder:
            return label
    return None

# %%
def prepare_data(output_directory: str, image_limit: int = -1, use_labels=False, use_augmented=False, shuffle=False, copy=False):
    # Original database consists of raw & augmented dataset
    datasets = {
        'raw': RAW_DATA, 
    }
    
    if use_augmented:
        datasets['augmented'] = AUGMENTED_DATA
    
    # Number of images per label
    images_per_label = image_limit // 39
    
    # Images per dataset = Number of images (and labels) / Number of datasets
    images_per_dataset = images_per_label // len(datasets) if images_per_label > -1 else -1
    
    # Make sure to provide the number of images_per_label high enough to split raw & augmented data into train and test set
    # Therefore min_images_per_label is 6: ceil(6 / 2) = 3 => round(3 * 0.8) = 2 => train, test = 2, 1
    if images_per_dataset == -1 or ceil(0.9 * images_per_dataset) < images_per_dataset:
        
        print('🛠️ Data preparation in progress...')
        
        # Dictionary storing data
        data = {
            split: {
                key: [] for key in ['data', 'labels']
            } for split in ['train', 'test']
        }
        
        # Iterate over raw and augmented datasets
        for key, dir_path in datasets.items():
            print(f'\n\t⚙️ Loading {key} data...\n')
            for root, directories, files in os.walk(dir_path):
                folder = os.path.basename(root)
                loaded = 0
                if files: 
                    label = clean_label(folder)
                    if use_labels:
                        label = search_for_label(label)
                        assert label is not None, "Correspondig label should exist!"
                    if shuffle:
                        np.random.seed(42)
                        np.random.shuffle(files)

                    if images_per_dataset == -1:
                        N = len(files)
                    else:
                        N = images_per_dataset

                    # Split data into train and test set (9:1)
                    split_idx = [0, ceil(0.9 * N), N]

                    for i, split in enumerate(data):
                        if copy:
                            new_directory = os.path.join(output_directory, split, label)
                            if not os.path.isdir(new_directory):
                                os.makedirs(new_directory)
                            else:
                                shutil.rmtree(new_directory)
                                os.makedirs(new_directory)

                        start = split_idx[i]
                        end = split_idx[i + 1]

                        for j, file in enumerate(files[start: end], start=start + 1):
                            current_path = os.path.join(root, file)
                            if copy:
                                _, extension = os.path.splitext(file)
                                filename = f'{label}_{key}_{j}{extension}'
                                image_path = os.path.join(new_directory, filename)
                                shutil.copy(current_path, image_path)
                            else:
                                image_path = current_path
                            try:
                                image = transform_image(image_path, IMAGE_SIZE)
                                data[split]['data'].append(image)
                                data[split]['labels'].append(label)
                                loaded += 1
                                # print(f'[✔️] {image_path} successfully loaded')
                            # Broad exception clause due to possible cv2 errors
                            except Exception as error: # ValueError as error:
                                print(f'\t\t[❌] Error handled for {image_path}: {error}')
            
                    print(f"\t\t✔️ [{key.upper()}] {folder} ({label}): Successfully loaded {loaded} / {images_per_dataset} images")
                    
        
        print('\n\n📊 Summary:\n')
        for split in data:
            print(f"\t🗂️ {split.capitalize()}ing dataset contains of {len(data[split]['labels'])} images")
        
        return np.array(list(unpack(data)), dtype='object')
        
    else:
        print('[❌] Empty data returned. The image limit should be higher!')
        return np.empty(shape=(4,), dtype='object')

# %%
# Train and test data|
train_directory = os.path.join(DATA_DIRECTORY, 'train')
test_directory = os.path.join(DATA_DIRECTORY, 'test')

# Prepare data directories
X, y, X_test, y_test = prepare_data(
    DATA_DIRECTORY, 
    image_limit=IMAGE_LIMIT, 
    use_labels=True,
    use_augmented=False, 
    shuffle=True, 
    copy=False
)
# Out:
# 🛠️ Data preparation in progress...
#
# 	⚙️ Loading raw data...
#
# 		✔️ [RAW] Apple___Apple_scab (Scab): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Apple___Black_rot (Black_Rot): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Apple___Cedar_apple_rust (Rust): Successfully loaded 275 / 320 images
# 		✔️ [RAW] Apple___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Background_without_leaves (Background): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Blueberry___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Cherry___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Cherry___Powdery_mildew (Powdery_Mildew): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Corn___Cercospora_leaf_spot Gray_leaf_spot (Leaf_Spot): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Corn___Common_rust (Rust): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Corn___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Corn___Northern_Leaf_Blight (Blight): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Grape___Black_rot (Black_Rot): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Grape___Esca_(Black_Measles) (Black_Measles): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Grape___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Grape___Leaf_blight_(Isariopsis_Leaf_Spot) (Leaf_Spot): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Orange___Haunglongbing_(Citrus_greening) (Citrus_Greening): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Peach___Bacterial_spot (Bacterial_Spot): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Peach___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Pepper_bell___Bacterial_spot (Bacterial_Spot): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Pepper_bell___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Potato___Early_blight (Blight): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Potato___healthy (Healthy): Successfully loaded 152 / 320 images
# 		✔️ [RAW] Potato___Late_blight (Blight): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Raspberry___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Soybean___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Squash___Powdery_mildew (Powdery_Mildew): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Strawberry___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Strawberry___Leaf_scorch (Leaf_Scorch): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___Bacterial_spot (Bacterial_Spot): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___Early_blight (Blight): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___healthy (Healthy): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___Late_blight (Blight): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___Leaf_Mold (Leaf_Mold): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___Septoria_leaf_spot (Leaf_Spot): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___Spider_mites Two-spotted_spider_mite (Spider_Mites): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___Target_Spot (Target_Spot): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___Tomato_mosaic_virus (Mosaic_Virus): Successfully loaded 320 / 320 images
# 		✔️ [RAW] Tomato___Tomato_Yellow_Leaf_Curl_Virus (Yellow_Leaf_Curl_Virus): Successfully loaded 320 / 320 images
#
#
# 📊 Summary:
#
# 	🗂️ Training dataset contains of 11083 images
# 	🗂️ Testing dataset contains of 1184 images

# %% [markdown]
# # Binarize training labels

# %%
def encode_labels(y, encoder, fit=False, save=False):
    if fit:
        y_bin = encoder.fit_transform(y)
        unique_binaries = pd.unique([np.argmax(x) for x in y_bin])
        unique_labels = pd.unique(y)

        assert dict(zip(unique_binaries, unique_labels)) == {np.argmax(x): y[i] for i, x in enumerate(y_bin)}, 'Ambiguity in labels!'

        encoded_labels = dict(zip(unique_binaries, unique_labels))
        if save:
            if not os.path.isdir(LABELS_DIRECTORY):
                os.makedirs(LABELS_DIRECTORY, exist_ok=True)
            output_pickle = os.path.join(LABELS_DIRECTORY, 'happy_plant_labels.pickle')
            with open(output_pickle, 'wb') as file:
                pickle.dump(encoded_labels, file)
                print(f'💾 Labels saved as {output_pickle}\n')
        return y_bin, encoded_labels
    else:
        y_bin = encoder.transform(y)
        return y_bin

# %%
label_binarizer = LabelBinarizer() 

# Binarization of multiple classes can increase the accuracy
y_bin, encoded_labels = encode_labels(y, label_binarizer, fit=True, save=True)

print('🦕 Encoded labels:\n')
for k, v in sorted(encoded_labels.items()):
    print(f'\t{k}: {v}')
    
n_classes = len(encoded_labels)
print(f'\n🪐 There are {n_classes} plant disease classes')
# Out:
# 💾 Labels saved as data\models\labels\happy_plant_labels.pickle
#
# 🦕 Encoded labels:
#
# 	0: Background
# 	1: Bacterial_Spot
# 	2: Black_Measles
# 	3: Black_Rot
# 	4: Blight
# 	5: Citrus_Greening
# 	6: Healthy
# 	7: Leaf_Mold
# 	8: Leaf_Scorch
# 	9: Leaf_Spot
# 	10: Mosaic_Virus
# 	11: Powdery_Mildew
# 	12: Rust
# 	13: Scab
# 	14: Spider_Mites
# 	15: Target_Spot
# 	16: Yellow_Leaf_Curl_Virus
#
# 🪐 There are 17 plant disease classes

# %% [markdown]
# # Split data into train and validation set

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X, 
    y_bin, 
    train_size=0.8, 
    random_state=42
)

# %%
assert X.shape[0] == y_bin.shape[0], 'X != y_bin'
assert X_train.shape[0] == y_train.shape[0], 'X_train != y_train'
assert X_valid.shape[0] == y_valid.shape[0], 'X_valid != y_valid'
assert X_test.shape[0] == y_test.shape[0], 'X_test != y_test'

# %% [markdown]
# # Build and train the model
#
# In most convolutional networks, the higher up a layer is, the more specialized it is. The first few layers learn very simple and generic features that generalize to almost all types of images. As you go higher up, the features are increasingly more specific to the dataset on which the model was trained. The goal of fine-tuning is to adapt these specialized features to work with the new dataset, rather than overwrite the generic learning.

# %%
def compile_model(model, learning_rate):
    model.compile(
        optimizer=Adam(lr=learning_rate),
        loss=BinaryCrossentropy(from_logits=True),
        metrics=[
            CategoricalAccuracy(name='Accuracy'),
            Precision(name='Precision'), 
            Recall(name='Recall')
        ]
    )   
    return model

# %%
def train_model(
    model, 
    X_train, 
    y_train, 
    X_valid, 
    y_valid, 
    n_epochs=50,
    batch_size=32,
    apply_image_preprocessing=False,
    use_early_stopping=False,
    use_reduce_lr=False,
    use_checkpoint=False,
    checkpoint_path=''
):
    
    timestamp = datetime.strftime(datetime.now(), '%Y%m%d_%H%M%S')
    callbacks = []
    
    # Stop learning as soon as validation loss remains unchanged for 5 epochs
    if use_early_stopping:
        early_stopping = EarlyStopping(
            monitor ="val_loss",  
            mode ="min", 
            patience=5,  
            restore_best_weights=True,
            verbose=1
        )
        callbacks.append(early_stopping)

    # Checkpoint model weights 
    if use_checkpoint:
        if not checkpoint_path:
            checkpoint_path = os.path.join(MODELS_DIRECTORY, 'Model', 'model.hdf5')
        path, ext = os.path.splitext(checkpoint_path)
        checkpoint_path = f"{path}_{timestamp}{ext}"
        checkpoint = ModelCheckpoint(
            checkpoint_path,
            monitor='val_loss',
            mode='min',
            save_best_only=True,
            verbose=1
        )
        callbacks.append(checkpoint)
    
    # If no reducement of validation loss is present, learning rate is reduced
    if use_reduce_lr:
        reduce_lr = ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=3,
            cooldown=5,
            verbose=1
        )
        callbacks.append(reduce_lr)

    if apply_image_preprocessing:
        image_gen = ImageDataGenerator(
            rotation_range=60,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.2,
            zoom_range=0.2,
            brightness_range=[0.75, 1.25],
            horizontal_flip=True,
        )
        
        history = model.fit(
            image_gen.flow(X_train, y_train, batch_size=batch_size),
            validation_data=(X_valid, y_valid),
            epochs=n_epochs,
            callbacks=callbacks,
            verbose=1
        ).history
    
    else:
        history = model.fit(
            x=X_train,
            y=y_train,
            batch_size=batch_size,
            validation_data=(X_valid, y_valid),
            epochs=n_epochs,
            callbacks=callbacks,
            verbose=1
        ).history
    
    return history

# %% [markdown]
# # MobileNetV2

# %%
def trainable_layers(model) -> int:
    trainable = 0
    for layer in model.layers:
        if 'mobilenetv2' in layer.name:
            all_layers = len(layer.layers)
            trainable = sum([1 for mobile_layer in layer.layers if mobile_layer.trainable])
            return trainable - 1 if trainable < all_layers else trainable 
    return trainable

# %%
def mobile_net_v2(n_classes, learning_rate=1e-3, recent: str = "", limit_trainable: int = None):    
    if recent:
        print(f'[⚙️] Loading weights from {recent}')
        return load_model(recent)
    
    base_mobile_net_v2 = MobileNetV2(
        input_shape=INPUT_SHAPE,
        weights='imagenet',
        include_top=False
    )

    base_mobile_net_v2.trainable = True
    if isinstance(limit_trainable, int) and limit_trainable <= len(base_mobile_net_v2.layers):
        for layer in base_mobile_net_v2.layers[:-limit_trainable]:
            layer.trainable = False

    # Modify last layers
    input_layer = Input(shape=INPUT_SHAPE)
    hidden_layer = preprocess_input(input_layer)
    hidden_layer = base_mobile_net_v2(hidden_layer, training=False)
    hidden_layer = GlobalAveragePooling2D()(hidden_layer) 
    hidden_layer = Dense(1024, activation='relu')(hidden_layer)
    hidden_layer = Dense(1024, activation='relu')(hidden_layer)
    hidden_layer = Dense(512, activation='relu')(hidden_layer)
    hidden_layer = Dropout(rate=0.5)(hidden_layer)
    output_layer = Dense(n_classes, activation='softmax')(hidden_layer)

    mobile_net_v2_model = Model(inputs=input_layer, outputs=output_layer)

    return compile_model(mobile_net_v2_model, learning_rate)

# %% [markdown]
# # Fine-tuning

# %%
def generate_report(param_grid: dict) -> dict:
    return {parameter: {val: [] for val in values} for parameter, values in param_grid.items()}

# %%
def validation_results(report: dict):
    for parameter in report:
        results = sorted(report[parameter].items(), key=lambda item: item[1]['Accuracy'], reverse=True)
        for key, metrics in results:
            print(f'{parameter}: {key}')
            for metric, val in metrics.items():
                print(f' - {metric}: {val}')
            print('\n')

# %%
def parameter_validation(model_func, X_train, y_train, X_test, y_test, param_grid: dict, checkpoint_path: str = "", report: dict = {}) -> dict:
    if not report:
        report = generate_report(param_grid)
    
    for parameter in param_grid:
        for val in param_grid[parameter]:
            print(f'- {parameter}: {val}\n')
            model = model_func(n_classes, learning_rate=1e-4, **{parameter: val})
            train_model(
                model,
                X_train,
                y_train,
                X_valid,
                y_valid,
                n_epochs=50,
                batch_size=32,
                apply_image_preprocessing=True,
                use_reduce_lr=True,
                use_early_stopping=True,
                use_checkpoint=True,
                checkpoint_path=checkpoint_path
            )
            scores = model.evaluate(X_test, y_test, verbose=2)
            report[parameter][val] = dict(zip(['Accuracy', 'Precision', 'Recall'], scores[1:]))
            print('\n')

# %% [markdown]
# ## MobileNetV2 fine-tuning

# %%
mobile_net_v2_checkpoint_path = os.path.join(MODELS_DIRECTORY, 'MobileNetV2', 'mobile_net_v2.hdf5')
y_test_bin = encode_labels(y_test, label_binarizer)

mobile_net_v2_grid = {'limit_trainable': [25, 50, 100, 125, "All"]}
mobile_net_v2_results = generate_report(mobile_net_v2_grid)
parameter_validation(
    model_func=mobile_net_v2,
    X_train=X_train, 
    y_train=y_train, 
    X_test=X_test, 
    y_test=y_test_bin, 
    param_grid=mobile_net_v2_grid, 
    checkpoint_path=mobile_net_v2_checkpoint_path,
    report=mobile_net_v2_results
)
# Out:
# - limit_trainable: 25
#
# Epoch 1/50
# 278/278 [==============================] - 123s 396ms/step - loss: 0.2036 - accuracy: 0.3910 - precision: 0.6265 - Recall: 0.2629 - val_loss: 0.0603 - val_accuracy: 0.8047 - val_precision: 0.8579 - val_Recall: 0.7627
#
# Epoch 00001: val_loss improved from inf to 0.06032, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 2/50
# 278/278 [==============================] - 106s 382ms/step - loss: 0.0702 - accuracy: 0.7968 - precision: 0.8572 - Recall: 0.7509 - val_loss: 0.0381 - val_accuracy: 0.8787 - val_precision: 0.8957 - val_Recall: 0.8642
#
# Epoch 00002: val_loss improved from 0.06032 to 0.03809, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 3/50
# 278/278 [==============================] - 108s 389ms/step - loss: 0.0452 - accuracy: 0.8665 - precision: 0.8951 - Recall: 0.8467 - val_loss: 0.0359 - val_accuracy: 0.8913 - val_precision: 0.9038 - val_Recall: 0.8859
#
# Epoch 00003: val_loss improved from 0.03809 to 0.03589, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 4/50
# 278/278 [==============================] - 106s 380ms/step - loss: 0.0361 - accuracy: 0.8948 - precision: 0.9120 - Recall: 0.8830 - val_loss: 0.0553 - val_accuracy: 0.8588 - val_precision: 0.8701 - val_Recall: 0.8521
#
# Epoch 00004: val_loss did not improve from 0.03589
# Epoch 5/50
# 278/278 [==============================] - 105s 377ms/step - loss: 0.0334 - accuracy: 0.9042 - precision: 0.9182 - Recall: 0.8934 - val_loss: 0.0263 - val_accuracy: 0.9206 - val_precision: 0.9245 - val_Recall: 0.9175
#
# Epoch 00005: val_loss improved from 0.03589 to 0.02633, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 6/50
# 278/278 [==============================] - 106s 380ms/step - loss: 0.0250 - accuracy: 0.9299 - precision: 0.9416 - Recall: 0.9225 - val_loss: 0.0301 - val_accuracy: 0.9111 - val_precision: 0.9189 - val_Recall: 0.9048
#
# Epoch 00006: val_loss did not improve from 0.02633
# Epoch 7/50
# 278/278 [==============================] - 105s 378ms/step - loss: 0.0253 - accuracy: 0.9251 - precision: 0.9358 - Recall: 0.9181 - val_loss: 0.0260 - val_accuracy: 0.9233 - val_precision: 0.9322 - val_Recall: 0.9184
#
# Epoch 00007: val_loss improved from 0.02633 to 0.02597, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 8/50
# 278/278 [==============================] - 105s 377ms/step - loss: 0.0238 - accuracy: 0.9301 - precision: 0.9390 - Recall: 0.9239 - val_loss: 0.0253 - val_accuracy: 0.9301 - val_precision: 0.9336 - val_Recall: 0.9265
#
# Epoch 00008: val_loss improved from 0.02597 to 0.02529, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 9/50
# 278/278 [==============================] - 105s 379ms/step - loss: 0.0204 - accuracy: 0.9442 - precision: 0.9484 - Recall: 0.9392 - val_loss: 0.0188 - val_accuracy: 0.9423 - val_precision: 0.9456 - val_Recall: 0.9405
#
# Epoch 00009: val_loss improved from 0.02529 to 0.01877, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 10/50
# 278/278 [==============================] - 105s 377ms/step - loss: 0.0194 - accuracy: 0.9446 - precision: 0.9485 - Recall: 0.9418 - val_loss: 0.0215 - val_accuracy: 0.9359 - val_precision: 0.9413 - val_Recall: 0.9332
#
# Epoch 00010: val_loss did not improve from 0.01877
# Epoch 11/50
# 278/278 [==============================] - 105s 377ms/step - loss: 0.0174 - accuracy: 0.9477 - precision: 0.9527 - Recall: 0.9441 - val_loss: 0.0259 - val_accuracy: 0.9269 - val_precision: 0.9285 - val_Recall: 0.9260
#
# Epoch 00011: val_loss did not improve from 0.01877
# Epoch 12/50
# 278/278 [==============================] - 106s 382ms/step - loss: 0.0171 - accuracy: 0.9531 - precision: 0.9568 - Recall: 0.9484 - val_loss: 0.0211 - val_accuracy: 0.9423 - val_precision: 0.9448 - val_Recall: 0.9414
#
# Epoch 00012: val_loss did not improve from 0.01877
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 13/50
# 278/278 [==============================] - 106s 381ms/step - loss: 0.0124 - accuracy: 0.9645 - precision: 0.9682 - Recall: 0.9626 - val_loss: 0.0144 - val_accuracy: 0.9562 - val_precision: 0.9588 - val_Recall: 0.9558
#
# Epoch 00013: val_loss improved from 0.01877 to 0.01443, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 14/50
# 278/278 [==============================] - 106s 382ms/step - loss: 0.0084 - accuracy: 0.9767 - precision: 0.9784 - Recall: 0.9756 - val_loss: 0.0136 - val_accuracy: 0.9581 - val_precision: 0.9580 - val_Recall: 0.9562
#
# Epoch 00014: val_loss improved from 0.01443 to 0.01361, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 15/50
# 278/278 [==============================] - 106s 383ms/step - loss: 0.0080 - accuracy: 0.9769 - precision: 0.9776 - Recall: 0.9753 - val_loss: 0.0148 - val_accuracy: 0.9553 - val_precision: 0.9565 - val_Recall: 0.9531
#
# Epoch 00015: val_loss did not improve from 0.01361
# Epoch 16/50
# 278/278 [==============================] - 105s 379ms/step - loss: 0.0081 - accuracy: 0.9769 - precision: 0.9774 - Recall: 0.9752 - val_loss: 0.0127 - val_accuracy: 0.9644 - val_precision: 0.9665 - val_Recall: 0.9635
#
# Epoch 00016: val_loss improved from 0.01361 to 0.01265, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 17/50
# 278/278 [==============================] - 105s 377ms/step - loss: 0.0083 - accuracy: 0.9783 - precision: 0.9787 - Recall: 0.9770 - val_loss: 0.0165 - val_accuracy: 0.9585 - val_precision: 0.9593 - val_Recall: 0.9581
#
# Epoch 00017: val_loss did not improve from 0.01265
# Epoch 18/50
# 278/278 [==============================] - 105s 377ms/step - loss: 0.0077 - accuracy: 0.9775 - precision: 0.9790 - Recall: 0.9765 - val_loss: 0.0143 - val_accuracy: 0.9626 - val_precision: 0.9642 - val_Recall: 0.9608
#
# Epoch 00018: val_loss did not improve from 0.01265
# Epoch 19/50
# 278/278 [==============================] - 106s 380ms/step - loss: 0.0077 - accuracy: 0.9809 - precision: 0.9818 - Recall: 0.9794 - val_loss: 0.0133 - val_accuracy: 0.9612 - val_precision: 0.9620 - val_Recall: 0.9603
#
# Epoch 00019: val_loss did not improve from 0.01265
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 20/50
# 278/278 [==============================] - 105s 377ms/step - loss: 0.0067 - accuracy: 0.9813 - precision: 0.9825 - Recall: 0.9803 - val_loss: 0.0126 - val_accuracy: 0.9617 - val_precision: 0.9633 - val_Recall: 0.9603
#
# Epoch 00020: val_loss improved from 0.01265 to 0.01261, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 21/50
# 278/278 [==============================] - 105s 378ms/step - loss: 0.0059 - accuracy: 0.9831 - precision: 0.9843 - Recall: 0.9820 - val_loss: 0.0115 - val_accuracy: 0.9648 - val_precision: 0.9665 - val_Recall: 0.9639
#
# Epoch 00021: val_loss improved from 0.01261 to 0.01149, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 22/50
# 278/278 [==============================] - 105s 379ms/step - loss: 0.0057 - accuracy: 0.9842 - precision: 0.9850 - Recall: 0.9838 - val_loss: 0.0118 - val_accuracy: 0.9644 - val_precision: 0.9661 - val_Recall: 0.9630
#
# Epoch 00022: val_loss did not improve from 0.01149
# Epoch 23/50
# 278/278 [==============================] - 105s 378ms/step - loss: 0.0056 - accuracy: 0.9865 - precision: 0.9866 - Recall: 0.9853 - val_loss: 0.0123 - val_accuracy: 0.9617 - val_precision: 0.9633 - val_Recall: 0.9603
#
# Epoch 00023: val_loss did not improve from 0.01149
# Epoch 24/50
# 278/278 [==============================] - 105s 377ms/step - loss: 0.0052 - accuracy: 0.9852 - precision: 0.9862 - Recall: 0.9842 - val_loss: 0.0114 - val_accuracy: 0.9666 - val_precision: 0.9679 - val_Recall: 0.9657
#
# Epoch 00024: val_loss improved from 0.01149 to 0.01143, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_145033.hdf5
# Epoch 25/50
# 278/278 [==============================] - 106s 382ms/step - loss: 0.0051 - accuracy: 0.9863 - precision: 0.9875 - Recall: 0.9856 - val_loss: 0.0120 - val_accuracy: 0.9630 - val_precision: 0.9647 - val_Recall: 0.9626
#
# Epoch 00025: val_loss did not improve from 0.01143
# Epoch 26/50
# 278/278 [==============================] - 107s 384ms/step - loss: 0.0050 - accuracy: 0.9869 - precision: 0.9880 - Recall: 0.9863 - val_loss: 0.0130 - val_accuracy: 0.9630 - val_precision: 0.9639 - val_Recall: 0.9626
#
# Epoch 00026: val_loss did not improve from 0.01143
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# Epoch 27/50
# 278/278 [==============================] - 105s 379ms/step - loss: 0.0055 - accuracy: 0.9858 - precision: 0.9869 - Recall: 0.9850 - val_loss: 0.0124 - val_accuracy: 0.9635 - val_precision: 0.9648 - val_Recall: 0.9630
#
# Epoch 00027: val_loss did not improve from 0.01143
# Epoch 28/50
# 278/278 [==============================] - 106s 380ms/step - loss: 0.0046 - accuracy: 0.9861 - precision: 0.9874 - Recall: 0.9857 - val_loss: 0.0122 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_Recall: 0.9617
#
# Epoch 00028: val_loss did not improve from 0.01143
# Epoch 29/50
# 278/278 [==============================] - 106s 381ms/step - loss: 0.0049 - accuracy: 0.9855 - precision: 0.9863 - Recall: 0.9849 - val_loss: 0.0120 - val_accuracy: 0.9626 - val_precision: 0.9638 - val_Recall: 0.9617
# Restoring model weights from the end of the best epoch.
#
# Epoch 00029: val_loss did not improve from 0.01143
# Epoch 00029: early stopping
# 37/37 - 4s - loss: 0.0121 - accuracy: 0.9679 - precision: 0.9679 - Recall: 0.9671
#
#
# - limit_trainable: 50
#
# Epoch 1/50
# 278/278 [==============================] - 113s 389ms/step - loss: 0.2132 - accuracy: 0.3611 - precision: 0.6283 - Recall: 0.2352 - val_loss: 0.0587 - val_accuracy: 0.8128 - val_precision: 0.8847 - val_Recall: 0.7578
#
# Epoch 00001: val_loss improved from inf to 0.05870, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_154218.hdf5
# Epoch 2/50
# 278/278 [==============================] - 107s 384ms/step - loss: 0.0739 - accuracy: 0.7727 - precision: 0.8362 - Recall: 0.7234 - val_loss: 0.0439 - val_accuracy: 0.8620 - val_precision: 0.8829 - val_Recall: 0.8466
#
# Epoch 00002: val_loss improved from 0.05870 to 0.04386, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_154218.hdf5
# Epoch 3/50
# 278/278 [==============================] - 107s 385ms/step - loss: 0.0461 - accuracy: 0.8672 - precision: 0.8929 - Recall: 0.8409 - val_loss: 0.0248 - val_accuracy: 0.9215 - val_precision: 0.9331 - val_Recall: 0.9129
#
# Epoch 00003: val_loss improved from 0.04386 to 0.02480, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_154218.hdf5
# Epoch 4/50
# 278/278 [==============================] - 107s 384ms/step - loss: 0.0355 - accuracy: 0.8981 - precision: 0.9146 - Recall: 0.8858 - val_loss: 0.0285 - val_accuracy: 0.9093 - val_precision: 0.9250 - val_Recall: 0.9012
#
# Epoch 00004: val_loss did not improve from 0.02480
# Epoch 5/50
# 278/278 [==============================] - 107s 384ms/step - loss: 0.0293 - accuracy: 0.9165 - precision: 0.9273 - Recall: 0.9075 - val_loss: 0.0498 - val_accuracy: 0.8850 - val_precision: 0.8884 - val_Recall: 0.8764
#
# Epoch 00005: val_loss did not improve from 0.02480
# Epoch 6/50
# 278/278 [==============================] - 107s 384ms/step - loss: 0.0261 - accuracy: 0.9238 - precision: 0.9327 - Recall: 0.9166 - val_loss: 0.0286 - val_accuracy: 0.9206 - val_precision: 0.9258 - val_Recall: 0.9179
#
# Epoch 00006: val_loss did not improve from 0.02480
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 7/50
# 278/278 [==============================] - 108s 387ms/step - loss: 0.0146 - accuracy: 0.9606 - precision: 0.9641 - Recall: 0.9570 - val_loss: 0.0131 - val_accuracy: 0.9590 - val_precision: 0.9624 - val_Recall: 0.9576
#
# Epoch 00007: val_loss improved from 0.02480 to 0.01308, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_154218.hdf5
# Epoch 8/50
# 278/278 [==============================] - 107s 386ms/step - loss: 0.0115 - accuracy: 0.9680 - precision: 0.9724 - Recall: 0.9667 - val_loss: 0.0143 - val_accuracy: 0.9594 - val_precision: 0.9628 - val_Recall: 0.9581
#
# Epoch 00008: val_loss did not improve from 0.01308
# Epoch 9/50
# 278/278 [==============================] - 108s 389ms/step - loss: 0.0125 - accuracy: 0.9663 - precision: 0.9688 - Recall: 0.9632 - val_loss: 0.0122 - val_accuracy: 0.9617 - val_precision: 0.9633 - val_Recall: 0.9599
#
# Epoch 00009: val_loss improved from 0.01308 to 0.01224, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_154218.hdf5
# Epoch 10/50
# 278/278 [==============================] - 108s 389ms/step - loss: 0.0102 - accuracy: 0.9721 - precision: 0.9755 - Recall: 0.9697 - val_loss: 0.0111 - val_accuracy: 0.9666 - val_precision: 0.9679 - val_Recall: 0.9648
#
# Epoch 00010: val_loss improved from 0.01224 to 0.01115, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_154218.hdf5
# Epoch 11/50
# 278/278 [==============================] - 107s 383ms/step - loss: 0.0095 - accuracy: 0.9746 - precision: 0.9769 - Recall: 0.9726 - val_loss: 0.0116 - val_accuracy: 0.9653 - val_precision: 0.9687 - val_Recall: 0.9639
#
# Epoch 00011: val_loss did not improve from 0.01115
# Epoch 12/50
# 278/278 [==============================] - 107s 384ms/step - loss: 0.0087 - accuracy: 0.9743 - precision: 0.9759 - Recall: 0.9727 - val_loss: 0.0105 - val_accuracy: 0.9662 - val_precision: 0.9688 - val_Recall: 0.9662
#
# Epoch 00012: val_loss improved from 0.01115 to 0.01049, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_154218.hdf5
# Epoch 13/50
# 278/278 [==============================] - 107s 384ms/step - loss: 0.0082 - accuracy: 0.9771 - precision: 0.9793 - Recall: 0.9759 - val_loss: 0.0102 - val_accuracy: 0.9702 - val_precision: 0.9711 - val_Recall: 0.9693
#
# Epoch 00013: val_loss improved from 0.01049 to 0.01019, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_154218.hdf5
# Epoch 14/50
# 278/278 [==============================] - 107s 385ms/step - loss: 0.0077 - accuracy: 0.9795 - precision: 0.9808 - Recall: 0.9784 - val_loss: 0.0137 - val_accuracy: 0.9621 - val_precision: 0.9630 - val_Recall: 0.9617
#
# Epoch 00014: val_loss did not improve from 0.01019
# Epoch 15/50
# 278/278 [==============================] - 107s 384ms/step - loss: 0.0081 - accuracy: 0.9761 - precision: 0.9772 - Recall: 0.9749 - val_loss: 0.0093 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_Recall: 0.9734
#
# Epoch 00015: val_loss improved from 0.01019 to 0.00925, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_154218.hdf5
# Epoch 16/50
# 278/278 [==============================] - 108s 388ms/step - loss: 0.0083 - accuracy: 0.9767 - precision: 0.9782 - Recall: 0.9756 - val_loss: 0.0139 - val_accuracy: 0.9626 - val_precision: 0.9651 - val_Recall: 0.9612
#
# Epoch 00016: val_loss did not improve from 0.00925
# Epoch 17/50
# 278/278 [==============================] - 107s 385ms/step - loss: 0.0064 - accuracy: 0.9834 - precision: 0.9847 - Recall: 0.9826 - val_loss: 0.0107 - val_accuracy: 0.9698 - val_precision: 0.9706 - val_Recall: 0.9693
#
# Epoch 00017: val_loss did not improve from 0.00925
# Epoch 18/50
# 278/278 [==============================] - 108s 389ms/step - loss: 0.0064 - accuracy: 0.9820 - precision: 0.9830 - Recall: 0.9807 - val_loss: 0.0150 - val_accuracy: 0.9626 - val_precision: 0.9630 - val_Recall: 0.9621
#
# Epoch 00018: val_loss did not improve from 0.00925
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 19/50
# 278/278 [==============================] - 107s 384ms/step - loss: 0.0065 - accuracy: 0.9828 - precision: 0.9839 - Recall: 0.9819 - val_loss: 0.0094 - val_accuracy: 0.9738 - val_precision: 0.9747 - val_Recall: 0.9738
#
# Epoch 00019: val_loss did not improve from 0.00925
# Epoch 20/50
# 278/278 [==============================] - 107s 385ms/step - loss: 0.0046 - accuracy: 0.9878 - precision: 0.9889 - Recall: 0.9873 - val_loss: 0.0105 - val_accuracy: 0.9716 - val_precision: 0.9733 - val_Recall: 0.9707
# Restoring model weights from the end of the best epoch.
#
# Epoch 00020: val_loss did not improve from 0.00925
# Epoch 00020: early stopping
# 37/37 - 4s - loss: 0.0132 - accuracy: 0.9620 - precision: 0.9620 - Recall: 0.9620
#
#
# - limit_trainable: 100
#
# Epoch 1/50
# 278/278 [==============================] - 115s 398ms/step - loss: 0.2115 - accuracy: 0.3702 - precision: 0.5882 - Recall: 0.2439 - val_loss: 0.0618 - val_accuracy: 0.7853 - val_precision: 0.8367 - val_Recall: 0.7533
#
# Epoch 00001: val_loss improved from inf to 0.06183, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 2/50
# 278/278 [==============================] - 109s 392ms/step - loss: 0.0640 - accuracy: 0.8059 - precision: 0.8529 - Recall: 0.7738 - val_loss: 0.0503 - val_accuracy: 0.8687 - val_precision: 0.8796 - val_Recall: 0.8633
#
# Epoch 00002: val_loss improved from 0.06183 to 0.05030, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 3/50
# 278/278 [==============================] - 109s 393ms/step - loss: 0.0405 - accuracy: 0.8889 - precision: 0.9071 - Recall: 0.8707 - val_loss: 0.0296 - val_accuracy: 0.9098 - val_precision: 0.9161 - val_Recall: 0.9066
#
# Epoch 00003: val_loss improved from 0.05030 to 0.02964, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 4/50
# 278/278 [==============================] - 109s 394ms/step - loss: 0.0306 - accuracy: 0.9189 - precision: 0.9294 - Recall: 0.9098 - val_loss: 0.0321 - val_accuracy: 0.9008 - val_precision: 0.9164 - val_Recall: 0.8904
#
# Epoch 00004: val_loss did not improve from 0.02964
# Epoch 5/50
# 278/278 [==============================] - 109s 391ms/step - loss: 0.0270 - accuracy: 0.9285 - precision: 0.9371 - Recall: 0.9202 - val_loss: 0.0224 - val_accuracy: 0.9323 - val_precision: 0.9443 - val_Recall: 0.9256
#
# Epoch 00005: val_loss improved from 0.02964 to 0.02240, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 6/50
# 278/278 [==============================] - 109s 393ms/step - loss: 0.0222 - accuracy: 0.9416 - precision: 0.9498 - Recall: 0.9358 - val_loss: 0.0358 - val_accuracy: 0.9125 - val_precision: 0.9147 - val_Recall: 0.9089
#
# Epoch 00006: val_loss did not improve from 0.02240
# Epoch 7/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0195 - accuracy: 0.9504 - precision: 0.9556 - Recall: 0.9459 - val_loss: 0.0180 - val_accuracy: 0.9526 - val_precision: 0.9534 - val_Recall: 0.9508
#
# Epoch 00007: val_loss improved from 0.02240 to 0.01797, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 8/50
# 278/278 [==============================] - 109s 393ms/step - loss: 0.0219 - accuracy: 0.9389 - precision: 0.9457 - Recall: 0.9337 - val_loss: 0.0178 - val_accuracy: 0.9427 - val_precision: 0.9482 - val_Recall: 0.9405
#
# Epoch 00008: val_loss improved from 0.01797 to 0.01782, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 9/50
# 278/278 [==============================] - 109s 393ms/step - loss: 0.0164 - accuracy: 0.9544 - precision: 0.9592 - Recall: 0.9516 - val_loss: 0.0194 - val_accuracy: 0.9468 - val_precision: 0.9509 - val_Recall: 0.9441
#
# Epoch 00009: val_loss did not improve from 0.01782
# Epoch 10/50
# 278/278 [==============================] - 109s 393ms/step - loss: 0.0139 - accuracy: 0.9608 - precision: 0.9660 - Recall: 0.9588 - val_loss: 0.0147 - val_accuracy: 0.9626 - val_precision: 0.9659 - val_Recall: 0.9594
#
# Epoch 00010: val_loss improved from 0.01782 to 0.01468, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 11/50
# 278/278 [==============================] - 109s 393ms/step - loss: 0.0177 - accuracy: 0.9529 - precision: 0.9583 - Recall: 0.9489 - val_loss: 0.0120 - val_accuracy: 0.9644 - val_precision: 0.9687 - val_Recall: 0.9639
#
# Epoch 00011: val_loss improved from 0.01468 to 0.01198, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 12/50
# 278/278 [==============================] - 109s 391ms/step - loss: 0.0119 - accuracy: 0.9701 - precision: 0.9723 - Recall: 0.9675 - val_loss: 0.0275 - val_accuracy: 0.9184 - val_precision: 0.9236 - val_Recall: 0.9161
#
# Epoch 00012: val_loss did not improve from 0.01198
# Epoch 13/50
# 278/278 [==============================] - 109s 390ms/step - loss: 0.0133 - accuracy: 0.9642 - precision: 0.9676 - Recall: 0.9616 - val_loss: 0.0191 - val_accuracy: 0.9495 - val_precision: 0.9515 - val_Recall: 0.9477
#
# Epoch 00013: val_loss did not improve from 0.01198
# Epoch 14/50
# 278/278 [==============================] - 110s 394ms/step - loss: 0.0107 - accuracy: 0.9715 - precision: 0.9741 - Recall: 0.9697 - val_loss: 0.0210 - val_accuracy: 0.9436 - val_precision: 0.9461 - val_Recall: 0.9418
#
# Epoch 00014: val_loss did not improve from 0.01198
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 15/50
# 278/278 [==============================] - 109s 391ms/step - loss: 0.0054 - accuracy: 0.9866 - precision: 0.9873 - Recall: 0.9859 - val_loss: 0.0102 - val_accuracy: 0.9734 - val_precision: 0.9738 - val_Recall: 0.9725
#
# Epoch 00015: val_loss improved from 0.01198 to 0.01015, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 16/50
# 278/278 [==============================] - 111s 398ms/step - loss: 0.0037 - accuracy: 0.9904 - precision: 0.9910 - Recall: 0.9902 - val_loss: 0.0101 - val_accuracy: 0.9738 - val_precision: 0.9756 - val_Recall: 0.9738
#
# Epoch 00016: val_loss improved from 0.01015 to 0.01013, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 17/50
# 278/278 [==============================] - 109s 392ms/step - loss: 0.0038 - accuracy: 0.9902 - precision: 0.9906 - Recall: 0.9894 - val_loss: 0.0118 - val_accuracy: 0.9689 - val_precision: 0.9697 - val_Recall: 0.9680
#
# Epoch 00017: val_loss did not improve from 0.01013
# Epoch 18/50
# 278/278 [==============================] - 109s 392ms/step - loss: 0.0032 - accuracy: 0.9906 - precision: 0.9913 - Recall: 0.9900 - val_loss: 0.0097 - val_accuracy: 0.9743 - val_precision: 0.9760 - val_Recall: 0.9738
#
# Epoch 00018: val_loss improved from 0.01013 to 0.00966, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 19/50
# 278/278 [==============================] - 110s 396ms/step - loss: 0.0030 - accuracy: 0.9932 - precision: 0.9937 - Recall: 0.9927 - val_loss: 0.0087 - val_accuracy: 0.9765 - val_precision: 0.9779 - val_Recall: 0.9765
#
# Epoch 00019: val_loss improved from 0.00966 to 0.00871, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 20/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0031 - accuracy: 0.9923 - precision: 0.9925 - Recall: 0.9922 - val_loss: 0.0131 - val_accuracy: 0.9684 - val_precision: 0.9706 - val_Recall: 0.9680
#
# Epoch 00020: val_loss did not improve from 0.00871
# Epoch 21/50
# 278/278 [==============================] - 109s 392ms/step - loss: 0.0025 - accuracy: 0.9928 - precision: 0.9929 - Recall: 0.9924 - val_loss: 0.0093 - val_accuracy: 0.9761 - val_precision: 0.9770 - val_Recall: 0.9756
#
# Epoch 00021: val_loss did not improve from 0.00871
# Epoch 22/50
# 278/278 [==============================] - 109s 392ms/step - loss: 0.0027 - accuracy: 0.9922 - precision: 0.9929 - Recall: 0.9922 - val_loss: 0.0083 - val_accuracy: 0.9797 - val_precision: 0.9797 - val_Recall: 0.9797
#
# Epoch 00022: val_loss improved from 0.00871 to 0.00828, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 23/50
# 278/278 [==============================] - 110s 394ms/step - loss: 0.0034 - accuracy: 0.9898 - precision: 0.9901 - Recall: 0.9893 - val_loss: 0.0104 - val_accuracy: 0.9756 - val_precision: 0.9761 - val_Recall: 0.9756
#
# Epoch 00023: val_loss did not improve from 0.00828
# Epoch 24/50
# 278/278 [==============================] - 109s 393ms/step - loss: 0.0023 - accuracy: 0.9944 - precision: 0.9950 - Recall: 0.9938 - val_loss: 0.0105 - val_accuracy: 0.9770 - val_precision: 0.9774 - val_Recall: 0.9770
#
# Epoch 00024: val_loss did not improve from 0.00828
# Epoch 25/50
# 278/278 [==============================] - 109s 392ms/step - loss: 0.0038 - accuracy: 0.9894 - precision: 0.9899 - Recall: 0.9892 - val_loss: 0.0093 - val_accuracy: 0.9797 - val_precision: 0.9806 - val_Recall: 0.9797
#
# Epoch 00025: val_loss did not improve from 0.00828
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 26/50
# 278/278 [==============================] - 109s 393ms/step - loss: 0.0016 - accuracy: 0.9967 - precision: 0.9967 - Recall: 0.9964 - val_loss: 0.0083 - val_accuracy: 0.9811 - val_precision: 0.9815 - val_Recall: 0.9806
#
# Epoch 00026: val_loss improved from 0.00828 to 0.00827, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_161824.hdf5
# Epoch 27/50
# 278/278 [==============================] - 109s 392ms/step - loss: 0.0018 - accuracy: 0.9961 - precision: 0.9962 - Recall: 0.9957 - val_loss: 0.0099 - val_accuracy: 0.9783 - val_precision: 0.9788 - val_Recall: 0.9779
#
# Epoch 00027: val_loss did not improve from 0.00827
# Epoch 28/50
# 278/278 [==============================] - 109s 391ms/step - loss: 0.0016 - accuracy: 0.9955 - precision: 0.9957 - Recall: 0.9954 - val_loss: 0.0094 - val_accuracy: 0.9811 - val_precision: 0.9815 - val_Recall: 0.9811
#
# Epoch 00028: val_loss did not improve from 0.00827
# Epoch 29/50
# 278/278 [==============================] - 109s 391ms/step - loss: 0.0014 - accuracy: 0.9963 - precision: 0.9967 - Recall: 0.9962 - val_loss: 0.0098 - val_accuracy: 0.9802 - val_precision: 0.9806 - val_Recall: 0.9802
#
# Epoch 00029: val_loss did not improve from 0.00827
# Epoch 30/50
# 278/278 [==============================] - 109s 393ms/step - loss: 0.0010 - accuracy: 0.9979 - precision: 0.9979 - Recall: 0.9979 - val_loss: 0.0096 - val_accuracy: 0.9802 - val_precision: 0.9806 - val_Recall: 0.9802
#
# Epoch 00030: val_loss did not improve from 0.00827
# Epoch 31/50
# 278/278 [==============================] - 110s 396ms/step - loss: 0.0011 - accuracy: 0.9973 - precision: 0.9973 - Recall: 0.9973 - val_loss: 0.0099 - val_accuracy: 0.9793 - val_precision: 0.9792 - val_Recall: 0.9788
# Restoring model weights from the end of the best epoch.
#
# Epoch 00031: val_loss did not improve from 0.00827
# Epoch 00031: early stopping
# 37/37 - 3s - loss: 0.0101 - accuracy: 0.9772 - precision: 0.9772 - Recall: 0.9764
#
#
# - limit_trainable: 125
#
# Epoch 1/50
# 278/278 [==============================] - 116s 401ms/step - loss: 0.2294 - accuracy: 0.3147 - precision: 0.5366 - Recall: 0.1981 - val_loss: 0.0950 - val_accuracy: 0.6743 - val_precision: 0.7403 - val_Recall: 0.6441
#
# Epoch 00001: val_loss improved from inf to 0.09502, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 2/50
# 278/278 [==============================] - 110s 396ms/step - loss: 0.0835 - accuracy: 0.7252 - precision: 0.8067 - Recall: 0.6657 - val_loss: 0.0482 - val_accuracy: 0.8620 - val_precision: 0.8813 - val_Recall: 0.8471
#
# Epoch 00002: val_loss improved from 0.09502 to 0.04820, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 3/50
# 278/278 [==============================] - 110s 396ms/step - loss: 0.0508 - accuracy: 0.8506 - precision: 0.8814 - Recall: 0.8238 - val_loss: 0.0414 - val_accuracy: 0.8778 - val_precision: 0.8884 - val_Recall: 0.8728
#
# Epoch 00003: val_loss improved from 0.04820 to 0.04143, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 4/50
# 278/278 [==============================] - 110s 396ms/step - loss: 0.0340 - accuracy: 0.9045 - precision: 0.9194 - Recall: 0.8943 - val_loss: 0.0198 - val_accuracy: 0.9355 - val_precision: 0.9437 - val_Recall: 0.9305
#
# Epoch 00004: val_loss improved from 0.04143 to 0.01982, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 5/50
# 278/278 [==============================] - 110s 397ms/step - loss: 0.0341 - accuracy: 0.9064 - precision: 0.9215 - Recall: 0.8933 - val_loss: 0.0229 - val_accuracy: 0.9319 - val_precision: 0.9388 - val_Recall: 0.9274
#
# Epoch 00005: val_loss did not improve from 0.01982
# Epoch 6/50
# 278/278 [==============================] - 110s 394ms/step - loss: 0.0249 - accuracy: 0.9295 - precision: 0.9377 - Recall: 0.9225 - val_loss: 0.0235 - val_accuracy: 0.9355 - val_precision: 0.9423 - val_Recall: 0.9278
#
# Epoch 00006: val_loss did not improve from 0.01982
# Epoch 7/50
# 278/278 [==============================] - 110s 394ms/step - loss: 0.0186 - accuracy: 0.9484 - precision: 0.9552 - Recall: 0.9445 - val_loss: 0.0146 - val_accuracy: 0.9562 - val_precision: 0.9588 - val_Recall: 0.9544
#
# Epoch 00007: val_loss improved from 0.01982 to 0.01461, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 8/50
# 278/278 [==============================] - 111s 398ms/step - loss: 0.0191 - accuracy: 0.9461 - precision: 0.9515 - Recall: 0.9406 - val_loss: 0.0235 - val_accuracy: 0.9283 - val_precision: 0.9310 - val_Recall: 0.9256
#
# Epoch 00008: val_loss did not improve from 0.01461
# Epoch 9/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0220 - accuracy: 0.9360 - precision: 0.9430 - Recall: 0.9303 - val_loss: 0.0374 - val_accuracy: 0.9220 - val_precision: 0.9252 - val_Recall: 0.9206
#
# Epoch 00009: val_loss did not improve from 0.01461
# Epoch 10/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0203 - accuracy: 0.9411 - precision: 0.9484 - Recall: 0.9370 - val_loss: 0.0148 - val_accuracy: 0.9535 - val_precision: 0.9565 - val_Recall: 0.9513
#
# Epoch 00010: val_loss did not improve from 0.01461
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 11/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0100 - accuracy: 0.9747 - precision: 0.9769 - Recall: 0.9740 - val_loss: 0.0093 - val_accuracy: 0.9707 - val_precision: 0.9720 - val_Recall: 0.9707
#
# Epoch 00011: val_loss improved from 0.01461 to 0.00928, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 12/50
# 278/278 [==============================] - 111s 399ms/step - loss: 0.0054 - accuracy: 0.9867 - precision: 0.9873 - Recall: 0.9857 - val_loss: 0.0102 - val_accuracy: 0.9680 - val_precision: 0.9684 - val_Recall: 0.9675
#
# Epoch 00012: val_loss did not improve from 0.00928
# Epoch 13/50
# 278/278 [==============================] - 110s 396ms/step - loss: 0.0056 - accuracy: 0.9843 - precision: 0.9852 - Recall: 0.9831 - val_loss: 0.0107 - val_accuracy: 0.9734 - val_precision: 0.9738 - val_Recall: 0.9729
#
# Epoch 00013: val_loss did not improve from 0.00928
# Epoch 14/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0060 - accuracy: 0.9820 - precision: 0.9829 - Recall: 0.9815 - val_loss: 0.0106 - val_accuracy: 0.9707 - val_precision: 0.9711 - val_Recall: 0.9693
#
# Epoch 00014: val_loss did not improve from 0.00928
# Epoch 15/50
# 278/278 [==============================] - 110s 397ms/step - loss: 0.0066 - accuracy: 0.9837 - precision: 0.9845 - Recall: 0.9826 - val_loss: 0.0092 - val_accuracy: 0.9738 - val_precision: 0.9738 - val_Recall: 0.9734
#
# Epoch 00015: val_loss improved from 0.00928 to 0.00921, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 16/50
# 278/278 [==============================] - 111s 398ms/step - loss: 0.0051 - accuracy: 0.9859 - precision: 0.9869 - Recall: 0.9849 - val_loss: 0.0115 - val_accuracy: 0.9738 - val_precision: 0.9751 - val_Recall: 0.9734
#
# Epoch 00016: val_loss did not improve from 0.00921
# Epoch 17/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0056 - accuracy: 0.9842 - precision: 0.9853 - Recall: 0.9835 - val_loss: 0.0108 - val_accuracy: 0.9743 - val_precision: 0.9756 - val_Recall: 0.9738
#
# Epoch 00017: val_loss did not improve from 0.00921
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 18/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0038 - accuracy: 0.9893 - precision: 0.9896 - Recall: 0.9893 - val_loss: 0.0089 - val_accuracy: 0.9774 - val_precision: 0.9774 - val_Recall: 0.9770
#
# Epoch 00018: val_loss improved from 0.00921 to 0.00886, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 19/50
# 278/278 [==============================] - 110s 394ms/step - loss: 0.0027 - accuracy: 0.9927 - precision: 0.9929 - Recall: 0.9927 - val_loss: 0.0084 - val_accuracy: 0.9770 - val_precision: 0.9774 - val_Recall: 0.9770
#
# Epoch 00019: val_loss improved from 0.00886 to 0.00843, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 20/50
# 278/278 [==============================] - 110s 394ms/step - loss: 0.0030 - accuracy: 0.9908 - precision: 0.9909 - Recall: 0.9901 - val_loss: 0.0106 - val_accuracy: 0.9747 - val_precision: 0.9752 - val_Recall: 0.9747
#
# Epoch 00020: val_loss did not improve from 0.00843
# Epoch 21/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0036 - accuracy: 0.9896 - precision: 0.9900 - Recall: 0.9891 - val_loss: 0.0089 - val_accuracy: 0.9797 - val_precision: 0.9797 - val_Recall: 0.9797
#
# Epoch 00021: val_loss did not improve from 0.00843
# Epoch 22/50
# 278/278 [==============================] - 110s 397ms/step - loss: 0.0030 - accuracy: 0.9918 - precision: 0.9923 - Recall: 0.9913 - val_loss: 0.0084 - val_accuracy: 0.9806 - val_precision: 0.9810 - val_Recall: 0.9802
#
# Epoch 00022: val_loss improved from 0.00843 to 0.00835, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_171526.hdf5
# Epoch 23/50
# 278/278 [==============================] - 110s 397ms/step - loss: 0.0025 - accuracy: 0.9937 - precision: 0.9938 - Recall: 0.9935 - val_loss: 0.0089 - val_accuracy: 0.9779 - val_precision: 0.9779 - val_Recall: 0.9774
#
# Epoch 00023: val_loss did not improve from 0.00835
# Epoch 24/50
# 278/278 [==============================] - 111s 398ms/step - loss: 0.0032 - accuracy: 0.9910 - precision: 0.9915 - Recall: 0.9906 - val_loss: 0.0091 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_Recall: 0.9793
#
# Epoch 00024: val_loss did not improve from 0.00835
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# Epoch 25/50
# 278/278 [==============================] - 111s 397ms/step - loss: 0.0025 - accuracy: 0.9939 - precision: 0.9939 - Recall: 0.9938 - val_loss: 0.0091 - val_accuracy: 0.9797 - val_precision: 0.9797 - val_Recall: 0.9797
#
# Epoch 00025: val_loss did not improve from 0.00835
# Epoch 26/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0023 - accuracy: 0.9942 - precision: 0.9951 - Recall: 0.9941 - val_loss: 0.0092 - val_accuracy: 0.9797 - val_precision: 0.9797 - val_Recall: 0.9797
#
# Epoch 00026: val_loss did not improve from 0.00835
# Epoch 27/50
# 278/278 [==============================] - 110s 395ms/step - loss: 0.0029 - accuracy: 0.9927 - precision: 0.9934 - Recall: 0.9925 - val_loss: 0.0092 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_Recall: 0.9793
# Restoring model weights from the end of the best epoch.
#
# Epoch 00027: val_loss did not improve from 0.00835
# Epoch 00027: early stopping
# 37/37 - 4s - loss: 0.0099 - accuracy: 0.9747 - precision: 0.9746 - Recall: 0.9738
#
#
# - limit_trainable: All
#
# Epoch 1/50
# 278/278 [==============================] - 122s 417ms/step - loss: 0.2135 - accuracy: 0.3496 - precision: 0.5737 - Recall: 0.2200 - val_loss: 0.0591 - val_accuracy: 0.8047 - val_precision: 0.8496 - val_Recall: 0.7519
#
# Epoch 00001: val_loss improved from inf to 0.05911, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 2/50
# 278/278 [==============================] - 116s 415ms/step - loss: 0.0727 - accuracy: 0.7733 - precision: 0.8378 - Recall: 0.7271 - val_loss: 0.0299 - val_accuracy: 0.9057 - val_precision: 0.9237 - val_Recall: 0.8904
#
# Epoch 00002: val_loss improved from 0.05911 to 0.02986, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 3/50
# 278/278 [==============================] - 115s 413ms/step - loss: 0.0437 - accuracy: 0.8749 - precision: 0.8948 - Recall: 0.8597 - val_loss: 0.0358 - val_accuracy: 0.8958 - val_precision: 0.9064 - val_Recall: 0.8913
#
# Epoch 00003: val_loss did not improve from 0.02986
# Epoch 4/50
# 278/278 [==============================] - 115s 414ms/step - loss: 0.0341 - accuracy: 0.9067 - precision: 0.9214 - Recall: 0.8958 - val_loss: 0.0292 - val_accuracy: 0.9157 - val_precision: 0.9225 - val_Recall: 0.9125
#
# Epoch 00004: val_loss improved from 0.02986 to 0.02924, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 5/50
# 278/278 [==============================] - 116s 417ms/step - loss: 0.0280 - accuracy: 0.9238 - precision: 0.9314 - Recall: 0.9154 - val_loss: 0.0190 - val_accuracy: 0.9468 - val_precision: 0.9518 - val_Recall: 0.9432
#
# Epoch 00005: val_loss improved from 0.02924 to 0.01898, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 6/50
# 278/278 [==============================] - 116s 416ms/step - loss: 0.0262 - accuracy: 0.9262 - precision: 0.9332 - Recall: 0.9176 - val_loss: 0.0311 - val_accuracy: 0.9256 - val_precision: 0.9296 - val_Recall: 0.9233
#
# Epoch 00006: val_loss did not improve from 0.01898
# Epoch 7/50
# 278/278 [==============================] - 116s 417ms/step - loss: 0.0220 - accuracy: 0.9382 - precision: 0.9436 - Recall: 0.9349 - val_loss: 0.0236 - val_accuracy: 0.9323 - val_precision: 0.9364 - val_Recall: 0.9296
#
# Epoch 00007: val_loss did not improve from 0.01898
# Epoch 8/50
# 278/278 [==============================] - 116s 415ms/step - loss: 0.0181 - accuracy: 0.9474 - precision: 0.9512 - Recall: 0.9429 - val_loss: 0.0196 - val_accuracy: 0.9373 - val_precision: 0.9413 - val_Recall: 0.9337
#
# Epoch 00008: val_loss did not improve from 0.01898
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 9/50
# 278/278 [==============================] - 116s 416ms/step - loss: 0.0102 - accuracy: 0.9719 - precision: 0.9746 - Recall: 0.9678 - val_loss: 0.0119 - val_accuracy: 0.9653 - val_precision: 0.9652 - val_Recall: 0.9635
#
# Epoch 00009: val_loss improved from 0.01898 to 0.01192, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 10/50
# 278/278 [==============================] - 117s 419ms/step - loss: 0.0070 - accuracy: 0.9812 - precision: 0.9833 - Recall: 0.9806 - val_loss: 0.0112 - val_accuracy: 0.9693 - val_precision: 0.9697 - val_Recall: 0.9684
#
# Epoch 00010: val_loss improved from 0.01192 to 0.01119, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 11/50
# 278/278 [==============================] - 116s 416ms/step - loss: 0.0058 - accuracy: 0.9848 - precision: 0.9864 - Recall: 0.9841 - val_loss: 0.0087 - val_accuracy: 0.9756 - val_precision: 0.9765 - val_Recall: 0.9747
#
# Epoch 00011: val_loss improved from 0.01119 to 0.00873, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 12/50
# 278/278 [==============================] - 116s 416ms/step - loss: 0.0061 - accuracy: 0.9831 - precision: 0.9842 - Recall: 0.9822 - val_loss: 0.0120 - val_accuracy: 0.9644 - val_precision: 0.9648 - val_Recall: 0.9639
#
# Epoch 00012: val_loss did not improve from 0.00873
# Epoch 13/50
# 278/278 [==============================] - 115s 414ms/step - loss: 0.0064 - accuracy: 0.9853 - precision: 0.9859 - Recall: 0.9845 - val_loss: 0.0100 - val_accuracy: 0.9707 - val_precision: 0.9711 - val_Recall: 0.9707
#
# Epoch 00013: val_loss did not improve from 0.00873
# Epoch 14/50
# 278/278 [==============================] - 115s 413ms/step - loss: 0.0064 - accuracy: 0.9815 - precision: 0.9826 - Recall: 0.9807 - val_loss: 0.0086 - val_accuracy: 0.9756 - val_precision: 0.9774 - val_Recall: 0.9752
#
# Epoch 00014: val_loss improved from 0.00873 to 0.00855, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 15/50
# 278/278 [==============================] - 116s 415ms/step - loss: 0.0047 - accuracy: 0.9867 - precision: 0.9876 - Recall: 0.9857 - val_loss: 0.0098 - val_accuracy: 0.9743 - val_precision: 0.9747 - val_Recall: 0.9738
#
# Epoch 00015: val_loss did not improve from 0.00855
# Epoch 16/50
# 278/278 [==============================] - 115s 413ms/step - loss: 0.0051 - accuracy: 0.9867 - precision: 0.9881 - Recall: 0.9864 - val_loss: 0.0107 - val_accuracy: 0.9734 - val_precision: 0.9742 - val_Recall: 0.9720
#
# Epoch 00016: val_loss did not improve from 0.00855
# Epoch 17/50
# 278/278 [==============================] - 115s 414ms/step - loss: 0.0050 - accuracy: 0.9864 - precision: 0.9872 - Recall: 0.9860 - val_loss: 0.0130 - val_accuracy: 0.9630 - val_precision: 0.9643 - val_Recall: 0.9621
#
# Epoch 00017: val_loss did not improve from 0.00855
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 18/50
# 278/278 [==============================] - 115s 413ms/step - loss: 0.0037 - accuracy: 0.9902 - precision: 0.9913 - Recall: 0.9895 - val_loss: 0.0083 - val_accuracy: 0.9788 - val_precision: 0.9788 - val_Recall: 0.9788
#
# Epoch 00018: val_loss improved from 0.00855 to 0.00834, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 19/50
# 278/278 [==============================] - 116s 415ms/step - loss: 0.0039 - accuracy: 0.9890 - precision: 0.9900 - Recall: 0.9887 - val_loss: 0.0079 - val_accuracy: 0.9793 - val_precision: 0.9797 - val_Recall: 0.9783
#
# Epoch 00019: val_loss improved from 0.00834 to 0.00793, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 20/50
# 278/278 [==============================] - 116s 415ms/step - loss: 0.0035 - accuracy: 0.9912 - precision: 0.9921 - Recall: 0.9908 - val_loss: 0.0080 - val_accuracy: 0.9783 - val_precision: 0.9788 - val_Recall: 0.9779
#
# Epoch 00020: val_loss did not improve from 0.00793
# Epoch 21/50
# 278/278 [==============================] - 116s 414ms/step - loss: 0.0026 - accuracy: 0.9946 - precision: 0.9952 - Recall: 0.9945 - val_loss: 0.0098 - val_accuracy: 0.9770 - val_precision: 0.9774 - val_Recall: 0.9765
#
# Epoch 00021: val_loss did not improve from 0.00793
# Epoch 22/50
# 278/278 [==============================] - 115s 414ms/step - loss: 0.0032 - accuracy: 0.9914 - precision: 0.9916 - Recall: 0.9914 - val_loss: 0.0074 - val_accuracy: 0.9806 - val_precision: 0.9806 - val_Recall: 0.9806
#
# Epoch 00022: val_loss improved from 0.00793 to 0.00735, saving model to data\models\MobileNetV2\mobile_net_v2_20210516_180527.hdf5
# Epoch 23/50
# 278/278 [==============================] - 116s 416ms/step - loss: 0.0030 - accuracy: 0.9909 - precision: 0.9913 - Recall: 0.9905 - val_loss: 0.0078 - val_accuracy: 0.9797 - val_precision: 0.9797 - val_Recall: 0.9797
#
# Epoch 00023: val_loss did not improve from 0.00735
# Epoch 24/50
# 278/278 [==============================] - 115s 414ms/step - loss: 0.0033 - accuracy: 0.9903 - precision: 0.9906 - Recall: 0.9898 - val_loss: 0.0088 - val_accuracy: 0.9774 - val_precision: 0.9783 - val_Recall: 0.9774
#
# Epoch 00024: val_loss did not improve from 0.00735
# Epoch 25/50
# 278/278 [==============================] - 116s 415ms/step - loss: 0.0027 - accuracy: 0.9938 - precision: 0.9939 - Recall: 0.9933 - val_loss: 0.0078 - val_accuracy: 0.9802 - val_precision: 0.9802 - val_Recall: 0.9802
#
# Epoch 00025: val_loss did not improve from 0.00735
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# Epoch 26/50
# 278/278 [==============================] - 116s 418ms/step - loss: 0.0029 - accuracy: 0.9925 - precision: 0.9930 - Recall: 0.9925 - val_loss: 0.0078 - val_accuracy: 0.9797 - val_precision: 0.9806 - val_Recall: 0.9788
#
# Epoch 00026: val_loss did not improve from 0.00735
# Epoch 27/50
# 278/278 [==============================] - 116s 418ms/step - loss: 0.0022 - accuracy: 0.9924 - precision: 0.9928 - Recall: 0.9924 - val_loss: 0.0076 - val_accuracy: 0.9815 - val_precision: 0.9815 - val_Recall: 0.9811
# Restoring model weights from the end of the best epoch.
#
# Epoch 00027: val_loss did not improve from 0.00735
# Epoch 00027: early stopping
# 37/37 - 3s - loss: 0.0085 - accuracy: 0.9755 - precision: 0.9755 - Recall: 0.9747

# %% [markdown]
# ## MobileNetV2 CV Results

# %%
validation_results(mobile_net_v2_results)
# Out:
# limit_trainable: 100
#  - Accuracy: 0.9771959185600281
#  - Precision: 0.9771766662597656
#  - Recall: 0.9763513803482056
#
#
# limit_trainable: All
#  - Accuracy: 0.9755067825317383
#  - Precision: 0.9754860401153564
#  - Recall: 0.974662184715271
#
#
# limit_trainable: 125
#  - Accuracy: 0.974662184715271
#  - Precision: 0.9746407270431519
#  - Recall: 0.9738175868988037
#
#
# limit_trainable: 25
#  - Accuracy: 0.9679054021835327
#  - Precision: 0.9678782820701599
#  - Recall: 0.9670608043670654
#
#
# limit_trainable: 50
#  - Accuracy: 0.9619932174682617
#  - Precision: 0.9619932174682617
#  - Recall: 0.9619932174682617

# %% [markdown]
# # Predict

# %%
def predict_disease(model, encoded_labels, x_test: str or np.ndarray, y_true=None, plot=False):
    if os.path.isfile(x_test):
        image = load_img(x_test)
        image_array = img_to_array(image)
    else:
        image = array_to_img(x_test)
        image_array = x_test
    
    y_pred = np.argmax(model.predict(np.expand_dims(image_array, axis=0)), axis=-1)[0]
        
    print(f'Prediction: {encoded_labels[y_pred]}')
    if y_true:
        print(f'Actual Disease: {y_true}')
    
    if plot:
        plt.imshow(image)
        plt.show()

# %% [markdown]
# # Reuse model

# %%
def get_latest_model(root_dir: str) -> str:
    return max(glob.iglob(os.path.join(root_dir, '*.hdf5')), key=os.path.getctime)

# %%
y_test_bin = encode_labels(y_test, label_binarizer)

# %%
new_mobile_net_v2 = mobile_net_v2(n_classes, recent=get_latest_model(r'data/models/MobileNetV2/'), limit_trainable=50)
mobile_net_v2_scores = new_mobile_net_v2.evaluate(X_test, y_test_bin, verbose=2)
# Out:
# [⚙️] Loading weights from data/models/MobileNetV2\mobile_net_v2_20210515_211513.hdf5
# 37/37 - 4s - loss: 0.0102 - accuracy: 0.9755 - precision: 0.9755 - Recall: 0.9755
